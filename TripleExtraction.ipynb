# %% [markdown]
# <a href="https://colab.research.google.com/github/AyushiKashyapp/foodwise_knowledgeDB/blob/main/TripleExtraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extracting relations from web pages.
#
# # Aim:
#
# The aim is to extract relations (triples) from wikipedia and other online information pages available for major stakeholders and committee members of Food Wise 2025 and Food Vision 2030 projects.
#
# The code overall follows these major steps:
#
# - Get the URLs for the stakeholder organisations and committee members from an excel.
# - Scrape the webpages and store the scrapped data in the form of a string to be tokenized.
# - Extract the entities and relations from the graph using ***rebel-large model***.
# - Export the extracted relations to an excel.

# %% [markdown]
# 1. **Installing required libraries.**
# - transformers  : Library provided by Hugging Face that provides general-purpose architectures (BERT, GPT-2, RoBERTa, etc.) for natural language understanding (NLU) and natural language generation (NLG).
# - wikipedia     : To access and parse data from Wikipedia.
# - newspaper3k   : Extracting and parsing articles from websites (including newspapers).
# - pyvis         : For visualization of graphs and networks.

# %%
# !pip install transformers wikipedia newspaper3k pyvis
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 5.0 MB/s eta 0:00:00
# Collecting GoogleNews
#   Downloading GoogleNews-1.6.14-py3-none-any.whl (8.5 kB)
# Collecting pyvis
#   Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from wikipedia) (4.12.3)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (9.4.0)
# Collecting cssselect>=0.9.2 (from newspaper3k)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.9.4)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (3.8.1)
# Collecting feedparser>=5.2.1 (from newspaper3k)
#   Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 5.9 MB/s eta 0:00:00
# Collecting tldextract>=2.0.1 (from newspaper3k)
#   Downloading tldextract-5.1.2-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 kB 4.8 MB/s eta 0:00:00
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 21.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.8.2)
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dateparser (from GoogleNews)
#   Downloading dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from pyvis) (7.34.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.1.4)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.2.1)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->wikipedia) (2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=5.3.0->pyvis)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 40.9 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9.6->pyvis) (2.1.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (1.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser->GoogleNews) (2023.4)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser->GoogleNews) (5.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.13)
# Building wheels for collected packages: wikipedia, tinysegmenter, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11680 sha256=1e63b26aeae41628bf5bcee67ccca0b3a09ac3f7d1386466c87e6ca5e41d38c2
#   Stored in directory: /root/.cache/pip/wheels/5e/b6/c5/93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13538 sha256=ec39852c0d65922464069f26e30bd9b114b2c4998b306ead8108637ea37d7bd0
#   Stored in directory: /root/.cache/pip/wheels/c8/d6/6c/384f58df48c00b9a31d638005143b5b3ac62c3d25fb1447f23
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3340 sha256=d282325bf654293cab95cdb390125716668db4c9efc75e8ea0ab844ca9e4710c
#   Stored in directory: /root/.cache/pip/wheels/97/02/e7/a1ff1760e12bdbaab0ac824fae5c1bc933e41c4ccd6a8f8edb
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398382 sha256=d50a43d7511dd2b7e61ac16faa647b03e3bc2fb44fecbbc0c511b34e67263a76
#   Stored in directory: /root/.cache/pip/wheels/7a/c4/0c/12a9a314ecac499456c4c3b2fcc2f635a3b45a39dfbd240299
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6049 sha256=334502e10852508f43789aac0f7485bc6c9d69a72622a40706b99817ec72e58e
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built wikipedia tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, jedi, feedparser, cssselect, wikipedia, requests-file, feedfinder2, dateparser, tldextract, pyvis, GoogleNews, newspaper3k
# Successfully installed GoogleNews-1.6.14 cssselect-1.2.0 dateparser-1.2.0 feedfinder2-0.0.4 feedparser-6.0.11 jedi-0.19.1 jieba3k-0.35.1 newspaper3k-0.2.8 pyvis-0.3.2 requests-file-2.1.0 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-5.1.2 wikipedia-1.4.0

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
import math
import torch
import wikipedia
from newspaper import Article, ArticleException
from GoogleNews import GoogleNews
import IPython
from pyvis.network import Network

# %% [markdown]
# 2. **Reading links**
#
# Reading the links corresponding to ***stakeholder organisations*** and ***committee members*** and storing the links in the list **urls**.

# %%
import pandas as pd

df = pd.read_excel('stakeholders.xlsx', sheet_name='Sheet1', engine='openpyxl')
urls = df['Links'].tolist()
print(urls)
# Out:
# ['https://birdwatch-europe.org/', 'https://www.fertilizer.org/', 'https://iitc.ie/', 'https://www.localroots.ie/', 'https://icmsa.ie/', 'https://www.thepimlicoproject.com/', 'https://en.wikipedia.org/wiki/Department_of_Transport_(Ireland)', 'https://en.wikipedia.org/wiki/Department_of_Agriculture,_Food_and_the_Marine', 'https://www.epa.ie/', 'https://www.creativead.ie/', 'https://www.glennonbrothers.ie/', 'https://en.wikipedia.org/wiki/Department_of_Public_Expenditure,_National_Development_Plan_Delivery_and_Reform', 'https://www.teagasc.ie/', 'https://bim.ie/', 'https://www.bordbia.ie/', 'https://en.wikipedia.org/wiki/Department_of_Finance_(Ireland)', 'https://en.wikipedia.org/wiki/Department_of_Housing,_Local_Government_and_Heritage', 'https://www.kerry.com/', 'https://www.danone.ie/', 'https://lic.ie/', 'https://www.oecd.org/agriculture/about/', 'https://loveirishfood.ie/brands/glenisk-2/', 'https://enterprise.gov.ie/en/who-we-are/offices-agencies/enterprise-ireland.html', 'https://en.wikipedia.org/wiki/Michael_Smurfit_Graduate_Business_School', 'https://en.wikipedia.org/wiki/Tom_Arnold_(economist)', 'https://www.musgravegroup.com/sharon-buckley-of-musgrave-named-a-wxn-2017-irelands-most-powerful-women-top-25-award-winner/', 'https://en.wikipedia.org/wiki/Enda_Kenny', 'https://en.wikipedia.org/wiki/Simon_Coveney', 'https://en.wikipedia.org/wiki/Michael_Creed', 'https://www.burrenlawschool.org/law/dr-brendan-dunford-0']

# %% [markdown]
# 3. **Loading the rebel-large model**.
#
# Loading a *tokenizer pretrained on the rebel-large model* from the Babelscape repository.
#
# Loading the *rebel-large model*, which is a large-scale pre-trained model for natural language processing tasks, provided by ***Babelscape***.

# %%
tokenizer = AutoTokenizer.from_pretrained("Babelscape/rebel-large")
model = AutoModelForSeq2SeqLM.from_pretrained("Babelscape/rebel-large")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/344 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]

# %% [markdown]
# 4. **Function to extract triples from a text.**
#
# This function processes a text output from a model that uses special tokens (triplet, subj, obj) to extract relationships.

# %%
def extract_relations_from_model_output(text):
    relations = [] #Store the extracted relationships as dictionaries.
    relation, subject, relation, object_ = '', '', '', '' #Hold the current relation type, subject, and object being processed.
    text = text.strip()
    current = 'x'
    text_replaced = text.replace("<s>", "").replace("<pad>", "").replace("</s>", "") #Removes special tokens
    for token in text_replaced.split(): #Iterates through each token in the processed text
        if token == "<triplet>": #start of a new triplet.
            current = 't'
            if relation != '':
                relations.append({
                    'head': subject.strip(),
                    'type': relation.strip(),
                    'tail': object_.strip()
                })
                relation = ''
            subject = ''
        elif token == "<subj>": #start of a subject in a triplet.
            current = 's'
            if relation != '':
                relations.append({
                    'head': subject.strip(),
                    'type': relation.strip(),
                    'tail': object_.strip()
                })
            object_ = ''
        elif token == "<obj>": #start of an object in a triplet.
            current = 'o'
            relation = ''
        else:
            if current == 't':
                subject += ' ' + token
            elif current == 's':
                object_ += ' ' + token
            elif current == 'o':
                relation += ' ' + token
    if subject != '' and relation != '' and object_ != '': #if relation is not empty, the current relation is added to relations list.
        relations.append({
            'head': subject.strip(),
            'type': relation.strip(),
            'tail': object_.strip()
        })
    return relations

# %% [markdown]
# 5. **Knowledge Base class.**
#
# The class KB (Knowledge Base) manages relations and provides methods to add, merge, and print them.

# %%
class KB():
    def __init__(self): #Initializing the KB class with an empty list relations to store relationship dictionaries.
        self.relations = []

    def are_relations_equal(self, r1, r2): #Checking if two relations r1 and r2 are equal based on their head, type, and tail attributes.
        return all(r1[attr] == r2[attr] for attr in ["head", "type", "tail"])

    def exists_relation(self, r1): #Checking if a given relation r1 already exists in the relations list.
        return any(self.are_relations_equal(r1, r2) for r2 in self.relations)

    def merge_relations(self, r1): #Merging the spans of two equal relations (r1 and r2) by adding spans from r1 that are not already in r2.
        r2 = [r for r in self.relations
              if self.are_relations_equal(r1, r)][0]
        spans_to_add = [span for span in r1["meta"]["spans"]
                        if span not in r2["meta"]["spans"]]
        r2["meta"]["spans"] += spans_to_add


    def add_relation(self, r): #Adding a new relation r to self.relations if it doesn't already exist (exists_relation returns False).
        if not self.exists_relation(r):
            self.relations.append(r)
        else:
            self.merge_relations(r)

    def print(self): #Printing all relations stored in self.relations in a formatted manner.
        print("Relations:")
        for r in self.relations:
            print(f"  {r}")

# %% [markdown]
# 6. **Function to organise the Knowledge Base.**
#
# Tokenizes the input text into spans, generates relations using a pretrained model, and organizes them into a knowledge base (KB) object.

# %%
def from_text_to_kb(text, span_length=128, verbose=False):
    # Tokenizing the input text using a pretrained tokenizer (tokenizer) and returns the tokenized inputs as PyTorch tensors
    inputs = tokenizer([text], return_tensors="pt")

    # compute span boundaries based on the length of input_ids and span_length.
    num_tokens = len(inputs["input_ids"][0])
    if verbose:
        print(f"Input has {num_tokens} tokens")
    num_spans = math.ceil(num_tokens / span_length)
    if verbose:
        print(f"Input has {num_spans} spans")
    overlap = math.ceil((num_spans * span_length - num_tokens) /
                        max(num_spans - 1, 1))
    spans_boundaries = []
    start = 0
    for i in range(num_spans):
        spans_boundaries.append([start + span_length * i,
                                 start + span_length * (i + 1)])
        start -= overlap
    if verbose:
        print(f"Span boundaries are {spans_boundaries}")

    # Transforms the tokenized input into spans by slicing input_ids and attention_mask tensors based on the computed spans_boundaries
    tensor_ids = [inputs["input_ids"][0][boundary[0]:boundary[1]]
                  for boundary in spans_boundaries]
    tensor_masks = [inputs["attention_mask"][0][boundary[0]:boundary[1]]
                    for boundary in spans_boundaries]
    inputs = {
        "input_ids": torch.stack(tensor_ids),
        "attention_mask": torch.stack(tensor_masks)
    }

    # Generates relations using a pretrained model (model.generate). Parameters for the generation are passed through gen_kwargs.
    num_return_sequences = 3
    gen_kwargs = {
        "max_length": 256,
        "length_penalty": 0,
        "num_beams": 3,
        "num_return_sequences": num_return_sequences
    }
    generated_tokens = model.generate(
        **inputs,
        **gen_kwargs,
    )

    # Decodes the generated tokens into relations using the tokenizer (tokenizer.batch_decode).
    decoded_preds = tokenizer.batch_decode(generated_tokens,
                                           skip_special_tokens=False)

    # Initializes a knowledge base (kb), iterates over the decoded predictions, extracts relations using extract_relations_from_model_output, and adds them to the KB.
    kb = KB()
    i = 0
    for sentence_pred in decoded_preds:
        current_span_index = i // num_return_sequences
        relations = extract_relations_from_model_output(sentence_pred)
        for relation in relations:
            relation["meta"] = {
                "spans": [spans_boundaries[current_span_index]]
            }
            kb.add_relation(relation)
        i += 1

    return kb

# %% [markdown]
# 7. **Function to extract web pages.**
#
# Extract and concatenate the text from multiple articles using the newspaper library.

# %%
from newspaper import Article, ArticleException

def article_extraction(url):
  all_text = [] #Initializing an empty list all_text to store the text content of each article.
  for url in urls:
        try:
            article = Article(url) #Iterates through each URL in urls, download and parse the article using the Article class from newspaper.
            article.download()
            article.parse()
            art_text = article.text #Extracting the text content
            all_text.append(art_text)
        except ArticleException as e:
            print(f"Error downloading or parsing article: {e}")

  return all_text

texts = article_extraction(urls)

text = ''.join(texts) #Concatenating all the text strings in texts into a single string text.
# Out:
# Error downloading or parsing article: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.oecd.org/agriculture/about/ on URL https://www.oecd.org/agriculture/about/

# %% [markdown]
# 8. **Text Cleaning**
#
# Removing the special characters, emojis and any other unwanted characters.

# %%
import re

def clean_text(text):
    # Remove special characters and punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # Remove emojis
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F700-\U0001F77F"  # alchemical symbols
                               u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                               u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                               u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                               u"\U0001FA00-\U0001FA6F"  # Chess Symbols
                               u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                               u"\U00002702-\U000027B0"  # Dingbats
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    text = emoji_pattern.sub(r'', text)

    # Remove unwanted characters
    # Add more characters inside [] to remove more unwanted characters
    text = re.sub(r'[\r\n\t\f\v]', ' ', text)  # Remove newlines and tabs

    return text.strip()  # Strip any leading or trailing whitespace


cleaned_text = clean_text(text)

# %% [markdown]
# 9. Spliting the complete text into smaller chunks.
#
# Since the rebel-large model cannot process texts over 1029 tokens, designed a function to to split a given text into chunks of a specified length (1029 tokens).

# %%
def create_chunks(text, chunk_length):
    chunks = []

    for i in range(0, len(text), chunk_length):
        chunks.append(text[i:i+chunk_length])

    return chunks

# %%
max_token_length = 1029
tokenized_text = create_chunks(cleaned_text, max_token_length)

# %%
print(tokenized_text[0])
# Out:
# And thats a wrap on IFA2024 in Singapore All of us at IFA would like to thank the 1189 delegates representing 552 companies from 72 countries who made it to Singapore for our Annual ConferenceCelebrating 100  Years in Business  Welcome to the IITC website We take pride in being one of Irelands largest Hardware Steel Salt and Agricultural Plastics and Plumbing distributors for the past 100 yearsWith our Jam Jar science project we hope to grow the smartest native oak trees in Ireland We are partnering with three National schools helping every student in 3rd class to grow their very own oak tree The acorn grows roots down into the jam jar and a hardy stem with leaves up into the air  all while just sitting on the class window sill The brains behind this initiative are our friends at OakyworldICMSA has represented farm families from all over Ireland at local national and European level with diligence passion integrity and an emphasis on finding solutions to their farmrelated problems for nearly 75 years That emphasis

# %%
len(cleaned_text)
# Out:
# 108478

# %% [markdown]
# **Testing from_text_to_kb on the first tokenized sentence.**

# %%
kb = from_text_to_kb(tokenized_text[0], verbose=True)
kb.print()
# Out:
# Input has 205 tokens
# Input has 2 spans
# Span boundaries are [[0, 128], [77, 205]]
# Relations:
#   {'head': 'IFA2024', 'type': 'country', 'tail': 'Singapore', 'meta': {'spans': [[0, 128]]}}
#   {'head': 'IFA2024', 'type': 'location', 'tail': 'Singapore', 'meta': {'spans': [[0, 128]]}}
#   {'head': 'IFA2024 in Singapore', 'type': 'country', 'tail': 'Singapore', 'meta': {'spans': [[0, 128]]}}
#   {'head': 'Jam Jar', 'type': 'subclass of', 'tail': 'jam jar', 'meta': {'spans': [[77, 205]]}}
#   {'head': 'oak tree', 'type': 'has parts of the class', 'tail': 'leaves', 'meta': {'spans': [[77, 205]]}}
#   {'head': 'acorn', 'type': 'subclass of', 'tail': 'leaves', 'meta': {'spans': [[77, 205]]}}

# %% [markdown]
# 10. **Creating complete knowledge base (KB).**
#
# Creating a knowledge base (KB) from text chunks by splitting the input text into chunks and generating relations for each chunk using another function from_text_to_kb.
#
# The function will iterate over the chunks, extract relations from each chunk and store the relationships from all the chunks by appending the relations from each chunk to a dictionary.

# %%
def create_kb_from_text_chunks(text, max_token_length=1029):
    chunks = create_chunks(text, max_token_length)
    relations_dict = {}

    for idx, chunk in enumerate(chunks):
        kb = from_text_to_kb(chunk, verbose=False)
        relations_dict[f'Chunk_{idx+1}'] = kb.relations

    return relations_dict

# %%
max_token_length = 1029
relations_dict = create_kb_from_text_chunks(cleaned_text, max_token_length)

# %%
for chunk, relations in relations_dict.items():
    print(f"Relations for {chunk}:")
    for relation in relations:
        print(relation)
# Out:
# Relations for Chunk_1:
# {'head': 'IFA2024', 'type': 'country', 'tail': 'Singapore', 'meta': {'spans': [[0, 128]]}}
# {'head': 'IFA2024', 'type': 'location', 'tail': 'Singapore', 'meta': {'spans': [[0, 128]]}}
# {'head': 'IFA2024 in Singapore', 'type': 'country', 'tail': 'Singapore', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Jam Jar', 'type': 'subclass of', 'tail': 'jam jar', 'meta': {'spans': [[77, 205]]}}
# {'head': 'oak tree', 'type': 'has parts of the class', 'tail': 'leaves', 'meta': {'spans': [[77, 205]]}}
# {'head': 'acorn', 'type': 'subclass of', 'tail': 'leaves', 'meta': {'spans': [[77, 205]]}}
# Relations for Chunk_2:
# {'head': 'democratic', 'type': 'subclass of', 'tail': 'nonpolitical', 'meta': {'spans': [[0, 128]]}}
# {'head': 'democratic', 'type': 'subclass of', 'tail': 'nondenominational', 'meta': {'spans': [[0, 128]]}}
# {'head': 'nonpolitical', 'type': 'subclass of', 'tail': 'democratic', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Dáil Éireann', 'type': 'has part', 'tail': 'Teachta Dála', 'meta': {'spans': [[62, 190]]}}
# {'head': 'Teachta Dála', 'type': 'part of', 'tail': 'Dáil Éireann', 'meta': {'spans': [[62, 190]]}}
# {'head': 'dairy farms', 'type': 'part of', 'tail': 'agricultural sector', 'meta': {'spans': [[62, 190]]}}
# {'head': 'dairy farms', 'type': 'subclass of', 'tail': 'agricultural sector', 'meta': {'spans': [[62, 190]]}}
# Relations for Chunk_3:
# {'head': 'Minister for Transport', 'type': 'part of', 'tail': 'Government of Ireland', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Government of Ireland', 'type': 'has part', 'tail': 'Minister for Transport', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Department of Transport Irish An Roinn Iompair', 'type': 'parent organization', 'tail': 'Government of Ireland', 'meta': {'spans': [[0, 128], [60, 188]]}}
# {'head': 'Department of Transport Irish An Roinn Iompair', 'type': 'office held by head of the organization', 'tail': 'Minister for Transport', 'meta': {'spans': [[0, 128], [60, 188]]}}
# {'head': 'Government of Ireland', 'type': 'subsidiary', 'tail': 'Department of Transport Irish An Roinn Iompair', 'meta': {'spans': [[0, 128], [60, 188]]}}
# {'head': 'Department of Transport Irish', 'type': 'parent organization', 'tail': 'Government of Ireland', 'meta': {'spans': [[60, 188]]}}
# {'head': 'Department of Transport Irish', 'type': 'office held by head of the organization', 'tail': 'Minister for Transport', 'meta': {'spans': [[60, 188]]}}
# {'head': 'Government of Ireland', 'type': 'subsidiary', 'tail': 'Department of Transport Irish', 'meta': {'spans': [[60, 188]]}}
# {'head': 'Minister for Transport', 'type': 'part of', 'tail': 'Department of Transport Irish', 'meta': {'spans': [[60, 188]]}}
# {'head': 'Minister for Transport', 'type': 'part of', 'tail': 'Department of Transport Irish An Roinn Iompair', 'meta': {'spans': [[60, 188]]}}
# {'head': 'Department of Transport Irish An Roinn Iompair', 'type': 'part of', 'tail': 'Government of Ireland', 'meta': {'spans': [[60, 188]]}}
# Relations for Chunk_4:
# {'head': 'Shannon', 'type': 'located in the administrative territorial entity', 'tail': 'County Clare', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Department of Transport and Power', 'type': 'inception', 'tail': '1959', 'meta': {'spans': [[0, 128], [73, 201]]}}
# {'head': 'Córas Iompair Éireann', 'type': 'subsidiary', 'tail': 'Dublin Airport Authority', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Dublin Airport Authority', 'type': 'parent organization', 'tail': 'Córas Iompair Éireann', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Department of Transport', 'type': 'dissolved, abolished or demolished date', 'tail': '2 January 1984', 'meta': {'spans': [[73, 201]]}}
# {'head': 'Department of the Public Service', 'type': 'inception', 'tail': '1973', 'meta': {'spans': [[73, 201]]}}
# Relations for Chunk_5:
# {'head': 'Department of Agriculture Food and the Marine', 'type': 'parent organization', 'tail': 'Government of Ireland', 'meta': {'spans': [[0, 128], [67, 195]]}}
# {'head': 'Government of Ireland', 'type': 'subsidiary', 'tail': 'Department of Agriculture Food and the Marine', 'meta': {'spans': [[0, 128], [67, 195]]}}
# {'head': 'Department of Finance', 'type': 'subsidiary', 'tail': 'Department of Tourism and Transport', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Department of Tourism and Transport', 'type': 'parent organization', 'tail': 'Department of Finance', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Minister for Agriculture Food and the Marine', 'type': 'part of', 'tail': 'Government of Ireland', 'meta': {'spans': [[67, 195]]}}
# {'head': 'Agriculture House Kildare Street', 'type': 'located in the administrative territorial entity', 'tail': 'Dublin', 'meta': {'spans': [[67, 195]]}}
# Relations for Chunk_6:
# {'head': 'European Union', 'type': 'instance of', 'tail': 'international', 'meta': {'spans': [[0, 128], [33, 161]]}}
# {'head': 'European Union', 'type': 'member of', 'tail': 'international', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Department of Agriculture Food and the Marine', 'type': 'headquarters location', 'tail': 'headquarters', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Joe Healy', 'type': 'award received', 'tail': 'Iris', 'meta': {'spans': [[33, 161]]}}
# {'head': 'EU law', 'type': 'applies to jurisdiction', 'tail': 'European Union', 'meta': {'spans': [[33, 161]]}}
# Relations for Chunk_7:
# {'head': 'Department of Agriculture', 'type': 'inception', 'tail': '1919', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Robert Barton', 'type': 'position held', 'tail': 'Minister for Agriculture', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Horace Plunkett', 'type': 'position held', 'tail': 'Minister for Agriculture', 'meta': {'spans': [[0, 128], [75, 203]]}}
# {'head': 'Department of Agriculture', 'type': 'office held by head of the organization', 'tail': 'Minister for Agriculture', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Minister for Agriculture', 'type': 'inception', 'tail': '1919', 'meta': {'spans': [[75, 203]]}}
# {'head': 'Ministry of Dáil Éireann', 'type': 'inception', 'tail': '1919', 'meta': {'spans': [[75, 203]]}}
# {'head': 'Ministers and Secretaries Act 1924', 'type': 'publication date', 'tail': '1924', 'meta': {'spans': [[75, 203]]}}
# Relations for Chunk_8:
# {'head': 'leases', 'type': 'subclass of', 'tail': 'tenure', 'meta': {'spans': [[0, 128]]}}
# {'head': 'lease', 'type': 'subclass of', 'tail': 'tenure', 'meta': {'spans': [[0, 128]]}}
# {'head': 'leases', 'type': 'subclass of', 'tail': 'tenure of lands acquisition', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Department', 'type': 'office held by head of the organization', 'tail': 'Minister for Lands and Agriculture', 'meta': {'spans': [[61, 189]]}}
# {'head': 'Minister for Lands and Agriculture', 'type': 'instance of', 'tail': 'Department', 'meta': {'spans': [[61, 189]]}}
# {'head': 'Minister for Lands and Agriculture', 'type': 'part of', 'tail': 'Department', 'meta': {'spans': [[61, 189]]}}
# Relations for Chunk_9:
# {'head': 'Water Quality in 2023 An Indicators Report', 'type': 'publisher', 'tail': 'Environmental Protection Agency', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Water Quality in 2023 An Indicators Report', 'type': 'author', 'tail': 'Environmental Protection Agency', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Glennon Brothers', 'type': 'inception', 'tail': '1913', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Troon', 'type': 'located in the administrative territorial entity', 'tail': 'Scotland', 'meta': {'spans': [[65, 193]]}}
# {'head': 'Glennon Brothers', 'type': 'headquarters location', 'tail': 'Longford', 'meta': {'spans': [[65, 193]]}}
# {'head': 'Glennon Brothers', 'type': 'location of formation', 'tail': 'Longford', 'meta': {'spans': [[65, 193]]}}
# Relations for Chunk_10:
# {'head': 'Minister for Public Expenditure', 'type': 'part of', 'tail': 'Government of Ireland', 'meta': {'spans': [[0, 128], [83, 211]]}}
# {'head': 'Government of Ireland', 'type': 'has part', 'tail': 'Minister for Public Expenditure', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Department of Public Expenditure', 'type': 'office held by head of the organization', 'tail': 'Minister for Public Expenditure', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Government Buildings', 'type': 'located in the administrative territorial entity', 'tail': 'Dublin', 'meta': {'spans': [[83, 211]]}}
# {'head': 'Merrion Street', 'type': 'located in the administrative territorial entity', 'tail': 'Dublin', 'meta': {'spans': [[83, 211]]}}
# Relations for Chunk_11:
# {'head': 'Department of Finance', 'type': 'instance of', 'tail': 'civil service', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Public Expenditure Division', 'type': 'part of', 'tail': 'Department of Finance', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Public Expenditure Division', 'type': 'parent organization', 'tail': 'Department of Finance', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Ministers and Secretaries Amendment Act 2011', 'type': 'publication date', 'tail': '2011', 'meta': {'spans': [[51, 179]]}}
# {'head': 'Ministers and Secretaries Amendment Act 2011', 'type': 'point in time', 'tail': '2011', 'meta': {'spans': [[51, 179]]}}
# {'head': 'Brendan Howlin', 'type': 'work period (start)', 'tail': '2011', 'meta': {'spans': [[51, 179]]}}
# Relations for Chunk_12:
# {'head': 'Department of Public Expenditure and Reform', 'type': 'inception', 'tail': '5 August 2011', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Department of Public Expenditure', 'type': 'inception', 'tail': '5 August 2011', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Ombudsman Amendment Act 2012', 'type': 'point in time', 'tail': '2012', 'meta': {'spans': [[58, 186]]}}
# {'head': 'Ombudsman Amendment Act 2012', 'type': 'publication date', 'tail': '2012', 'meta': {'spans': [[58, 186]]}}
# {'head': 'Houses of the Oireachtas Inquiries Privileges and Procedures Act 2013', 'type': 'point in time', 'tail': '2013', 'meta': {'spans': [[58, 186]]}}
# Relations for Chunk_13:
# {'head': 'Closures Act 2014', 'type': 'publication date', 'tail': '2014', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Closures Act 2014', 'type': 'point in time', 'tail': '2014', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Google Analytics', 'type': 'part of', 'tail': 'GoogleBIM', 'meta': {'spans': [[60, 188]]}}
# {'head': 'Google Analytics', 'type': 'developer', 'tail': 'GoogleBIM', 'meta': {'spans': [[60, 188]]}}
# {'head': 'Google Analytics', 'type': 'part of', 'tail': 'Universal Analytics', 'meta': {'spans': [[60, 188]]}}
# Relations for Chunk_14:
# {'head': 'Government of Ireland', 'type': 'office held by head of the organization', 'tail': 'Minister for Finance', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Minister for Finance', 'type': 'part of', 'tail': 'Government of Ireland', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Government of Ireland', 'type': 'country', 'tail': 'Republic of Ireland', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Minister for Finance', 'type': 'country', 'tail': 'Republic of Ireland', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Merrion Street', 'type': 'country', 'tail': 'Republic of Ireland', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Dublin', 'type': 'country', 'tail': 'Republic of Ireland', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Government Buildings Merrion Street', 'type': 'located in the administrative territorial entity', 'tail': 'Dublin', 'meta': {'spans': [[51, 179]]}}
# {'head': 'Government Buildings Merrion Street Dublin', 'type': 'country', 'tail': 'Republic of Ireland', 'meta': {'spans': [[51, 179]]}}
# {'head': 'Programme for Government', 'type': 'country', 'tail': 'Republic of Ireland', 'meta': {'spans': [[51, 179]]}}
# Relations for Chunk_15:
# {'head': 'Ministers and Secretaries Act 1924', 'type': 'publication date', 'tail': '1924', 'meta': {'spans': [[0, 128], [64, 192]]}}
# {'head': 'Ministers and Secretaries Act 1924', 'type': 'point in time', 'tail': '1924', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Irish Free State', 'type': 'inception', 'tail': '1922', 'meta': {'spans': [[0, 128], [64, 192]]}}
# {'head': 'Ministry of Finance', 'type': 'country', 'tail': 'Irish Republic', 'meta': {'spans': [[64, 192]]}}
# {'head': 'Ministry of Dáil Éireann', 'type': 'country', 'tail': 'Irish Republic', 'meta': {'spans': [[64, 192]]}}
# Relations for Chunk_16:
# {'head': 'Minister for Finance', 'type': 'part of', 'tail': 'Department of State', 'meta': {'spans': [[0, 128]]}}
# {'head': 'tAire Airgid', 'type': 'office held by head of the organization', 'tail': 'Minister for Finance', 'meta': {'spans': [[0, 128]]}}
# {'head': 'tAire Airgid', 'type': 'subclass of', 'tail': 'Minister for Finance', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Revenue Commissioners', 'type': 'parent organization', 'tail': 'British Treasury', 'meta': {'spans': [[66, 194]]}}
# {'head': 'British Treasury', 'type': 'applies to jurisdiction', 'tail': 'Ireland', 'meta': {'spans': [[66, 194]]}}
# {'head': 'tAire Airgid', 'type': 'position held', 'tail': 'Minister for Finance', 'meta': {'spans': [[66, 194]]}}
# Relations for Chunk_17:
# {'head': 'Department of the Public Service', 'type': 'inception', 'tail': '1973', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Department of Finance', 'type': 'inception', 'tail': '1973', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Department of Economic Planning', 'type': 'inception', 'tail': '1980', 'meta': {'spans': [[0, 128], [46, 174]]}}
# {'head': 'Department of Public Expenditure and Reform', 'type': 'inception', 'tail': 'July 2011', 'meta': {'spans': [[46, 174]]}}
# Relations for Chunk_18:
# {'head': 'Secretaries of the Department', 'type': 'subclass of', 'tail': 'Secretary of the Department', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Secretary of the Department', 'type': 'subclass of', 'tail': 'Secretaries of the Department', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Paddy Mullarkey', 'type': 'position held', 'tail': 'Secretary General of the Department', 'meta': {'spans': [[99, 227]]}}
# {'head': 'Tomás F Ó Cofaigh', 'type': 'date of birth', 'tail': '18 October 1977', 'meta': {'spans': [[99, 227]]}}
# {'head': 'Tomás F Ó Cofaigh', 'type': 'date of birth', 'tail': '31 October 1981', 'meta': {'spans': [[99, 227]]}}
# Relations for Chunk_19:
# {'head': 'Department of Housing Local Government and Heritage', 'type': 'parent organization', 'tail': 'Government of Ireland', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Government of Ireland', 'type': 'subsidiary', 'tail': 'Department of Housing Local Government and Heritage', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Department of Housing Local Government and Heritage', 'type': 'office held by head of the organization', 'tail': 'Minister for Housing Local Government and Heritage', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Minister for Housing Local Government and Heritage', 'type': 'part of', 'tail': 'Department of Housing Local Government and Heritage', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Department of Housing Local Government and Heritage', 'type': 'part of', 'tail': 'Government of Ireland', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Minister for Local Government', 'type': 'inception', 'tail': '1922', 'meta': {'spans': [[79, 207]]}}
# {'head': 'Department of Local Government and Public Health', 'type': 'inception', 'tail': '1922', 'meta': {'spans': [[79, 207]]}}
# {'head': 'Irish Free State', 'type': 'inception', 'tail': '1922', 'meta': {'spans': [[79, 207]]}}
# {'head': 'Executive Council of the Irish Free State', 'type': 'inception', 'tail': '1922', 'meta': {'spans': [[79, 207]]}}
# Relations for Chunk_20:
# {'head': '1924', 'type': 'point in time', 'tail': '1924', 'meta': {'spans': [[0, 128]]}}
# {'head': 'House of the Oireachtas', 'type': 'inception', 'tail': '1924', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Oireachtas', 'type': 'has part', 'tail': 'House of the Oireachtas', 'meta': {'spans': [[0, 128]]}}
# {'head': 'tAire Rialtais Aitiúla agus Sláinte Puiblí', 'type': 'office held by head of the organization', 'tail': 'Minister for Local Government and Public Health', 'meta': {'spans': [[64, 192]]}}
# {'head': 'Minister for Local Government and Public Health', 'type': 'instance of', 'tail': 'Department', 'meta': {'spans': [[64, 192]]}}
# {'head': 'Minister for Local Government and Public Health', 'type': 'part of', 'tail': 'tAire Rialtais Aitiúla agus Sláinte Puiblí', 'meta': {'spans': [[64, 192]]}}
# Relations for Chunk_21:
# {'head': 'National Health Insurance Commission', 'type': 'country', 'tail': 'Ireland', 'meta': {'spans': [[0, 128]]}}
# {'head': 'RegistrarGeneral of Births Deaths and Marriages in Ireland', 'type': 'country', 'tail': 'Ireland', 'meta': {'spans': [[0, 128]]}}
# {'head': 'potato chip', 'type': 'manufacturer', 'tail': 'Danone', 'meta': {'spans': [[59, 187]]}}
# {'head': 'potato chip', 'type': 'owned by', 'tail': 'Danone', 'meta': {'spans': [[59, 187]]}}
# {'head': 'Danone', 'type': 'owner of', 'tail': 'potato chip', 'meta': {'spans': [[59, 187]]}}
# Relations for Chunk_22:
# {'head': 'electronic communications network', 'type': 'subclass of', 'tail': 'transmission', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Statistics StatisticsGlenisk', 'type': 'instance of', 'tail': 'As Irelands bestl', 'meta': {'spans': [[0, 128]]}}
# {'head': 'As Irelands bestl', 'type': 'publisher', 'tail': 'Statistics StatisticsGlenisk', 'meta': {'spans': [[0, 128]]}}
# {'head': 'milk', 'type': 'subclass of', 'tail': 'dairy', 'meta': {'spans': [[53, 181]]}}
# {'head': 'yogurt', 'type': 'subclass of', 'tail': 'dairy', 'meta': {'spans': [[53, 181]]}}
# {'head': 'milk', 'type': 'subclass of', 'tail': 'dairy product', 'meta': {'spans': [[53, 181]]}}
# Relations for Chunk_23:
# {'head': 'Killeigh', 'type': 'located in the administrative territorial entity', 'tail': 'Co Offaly', 'meta': {'spans': [[0, 128], [69, 197]]}}
# {'head': 'Glenisk', 'type': 'located in the administrative territorial entity', 'tail': 'Killeigh Co Offaly', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Glenisk', 'type': 'located in the administrative territorial entity', 'tail': 'Killeigh', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Glenisk', 'type': 'product or material produced', 'tail': 'yogurt', 'meta': {'spans': [[69, 197]]}}
# {'head': 'Glenisk', 'type': 'headquarters location', 'tail': 'Killeigh', 'meta': {'spans': [[69, 197]]}}
# Relations for Chunk_24:
# {'head': 'organic milk', 'type': 'subclass of', 'tail': 'dairy products', 'meta': {'spans': [[0, 128]]}}
# {'head': 'organic milk', 'type': 'subclass of', 'tail': 'dairy product', 'meta': {'spans': [[0, 128]]}}
# {'head': 'live cultures', 'type': 'subclass of', 'tail': 'gut bacteria', 'meta': {'spans': [[0, 128]]}}
# {'head': 'milk', 'type': 'subclass of', 'tail': 'dairy', 'meta': {'spans': [[56, 184]]}}
# {'head': 'milk', 'type': 'subclass of', 'tail': 'organic', 'meta': {'spans': [[56, 184]]}}
# {'head': 'milk', 'type': 'subclass of', 'tail': 'organic cream', 'meta': {'spans': [[56, 184]]}}
# Relations for Chunk_25:
# {'head': 'research', 'type': 'has part', 'tail': 'innovation', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Government', 'type': 'subsidiary', 'tail': 'Enterprise Ireland', 'meta': {'spans': [[0, 128]]}}
# {'head': 'research', 'type': 'has cause', 'tail': 'innovation', 'meta': {'spans': [[0, 128]]}}
# {'head': 'innovation', 'type': 'has effect', 'tail': 'research', 'meta': {'spans': [[0, 128]]}}
# {'head': 'UCD Michael Smurfit Graduate Business School', 'type': 'instance of', 'tail': 'business school', 'meta': {'spans': [[48, 176]]}}
# {'head': 'Enterprise Ireland', 'type': 'instance of', 'tail': 'business school', 'meta': {'spans': [[48, 176]]}}
# Relations for Chunk_26:
# {'head': 'Quinn School of Business', 'type': 'inception', 'tail': '1908', 'meta': {'spans': [[0, 128]]}}
# {'head': 'UCD Faculty of Commerce', 'type': 'inception', 'tail': '1908', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Quinn School of Business', 'type': 'located in the administrative territorial entity', 'tail': 'Belfield', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Michael Smurfit Graduate Business School', 'type': 'member of', 'tail': 'Association to Advance Collegiate Schools of Business International', 'meta': {'spans': [[66, 194]]}}
# {'head': 'Michael Smurfit Graduate Business School', 'type': 'member of', 'tail': 'AACSB', 'meta': {'spans': [[66, 194]]}}
# {'head': 'Smurfit School', 'type': 'member of', 'tail': 'Association to Advance Collegiate Schools of Business International', 'meta': {'spans': [[66, 194]]}}
# Relations for Chunk_27:
# {'head': 'Smurfit Schools', 'type': 'instance of', 'tail': 'business school', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Michael Smurfit', 'type': 'occupation', 'tail': 'business executive', 'meta': {'spans': [[79, 207]]}}
# {'head': 'Tom Arnold', 'type': 'field of work', 'tail': 'agricultural economist', 'meta': {'spans': [[79, 207]]}}
# {'head': 'Tom Arnold', 'type': 'occupation', 'tail': 'agricultural economist', 'meta': {'spans': [[79, 207]]}}
# Relations for Chunk_28:
# {'head': 'Tom Arnold', 'type': 'educated at', 'tail': 'University College Dublin', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Tom Arnold', 'type': 'educated at', 'tail': 'Université catholique de Louvain', 'meta': {'spans': [[0, 128], [64, 192]]}}
# {'head': 'Tom Arnold', 'type': 'educated at', 'tail': 'Trinity College Dublin', 'meta': {'spans': [[0, 128], [64, 192]]}}
# {'head': 'Tom Arnold', 'type': 'position held', 'tail': 'European Commissioner for Social Affairs', 'meta': {'spans': [[64, 192]]}}
# Relations for Chunk_29:
# {'head': 'Irish Constitution', 'type': 'inception', 'tail': '1937', 'meta': {'spans': [[0, 128], [48, 176]]}}
# {'head': 'Concern Worldwide', 'type': 'instance of', 'tail': 'humanitarian agency', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Irish Constitution', 'type': 'publication date', 'tail': '1937', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Irish Constitutional Convention', 'type': 'end time', 'tail': 'March 2014', 'meta': {'spans': [[48, 176]]}}
# {'head': 'Irish Constitutional Convention', 'type': 'facet of', 'tail': 'Irish Constitution', 'meta': {'spans': [[48, 176]]}}
# Relations for Chunk_30:
# {'head': 'Ban Kimoon', 'type': 'position held', 'tail': 'UN SecretaryGeneral', 'meta': {'spans': [[0, 128]]}}
# {'head': 'David Nabarro', 'type': 'position held', 'tail': 'UN SecretaryGeneral', 'meta': {'spans': [[0, 128]]}}
# {'head': 'UN SecretaryGeneral', 'type': 'officeholder', 'tail': 'Ban Kimoon', 'meta': {'spans': [[0, 128]]}}
# {'head': 'SUN Movement', 'type': 'headquarters location', 'tail': 'Geneva', 'meta': {'spans': [[58, 186]]}}
# {'head': 'SUN secretariat', 'type': 'headquarters location', 'tail': 'Geneva', 'meta': {'spans': [[58, 186]]}}
# Relations for Chunk_31:
# {'head': 'Brexit', 'type': 'point in time', 'tail': '2016', 'meta': {'spans': [[0, 128]]}}
# {'head': 'UN Food Systems Summit 202021', 'type': 'point in time', 'tail': '2020', 'meta': {'spans': [[0, 128]]}}
# {'head': 'UN Food Systems Summit', 'type': 'point in time', 'tail': '2020', 'meta': {'spans': [[0, 128]]}}
# {'head': 'International Food Policy Research Institute', 'type': 'member of', 'tail': 'IFPRI', 'meta': {'spans': [[77, 205]]}}
# {'head': 'CGIAR', 'type': 'parent organization', 'tail': 'International Agricultural Research', 'meta': {'spans': [[77, 205]]}}
# {'head': 'International Food Policy Research Institute', 'type': 'part of', 'tail': 'IFPRI', 'meta': {'spans': [[77, 205]]}}
# Relations for Chunk_32:
# {'head': 'CERF', 'type': 'parent organization', 'tail': 'CERF', 'meta': {'spans': [[0, 128]]}}
# {'head': 'European Food Security Group', 'type': 'has part', 'tail': 'EFSG', 'meta': {'spans': [[0, 128]]}}
# {'head': 'EFSG', 'type': 'part of', 'tail': 'European Food Security Group', 'meta': {'spans': [[0, 128]]}}
# {'head': 'CERF', 'type': 'parent organization', 'tail': 'UN Central Emergency Response Fund', 'meta': {'spans': [[0, 128]]}}
# {'head': 'National University of Ireland', 'type': 'has part', 'tail': 'NUI', 'meta': {'spans': [[91, 219]]}}
# {'head': 'NUI', 'type': 'part of', 'tail': 'National University of Ireland', 'meta': {'spans': [[91, 219]]}}
# {'head': 'University College of Dublin', 'type': 'part of', 'tail': 'UCD', 'meta': {'spans': [[91, 219]]}}
# {'head': 'UCC College of Business and Law', 'type': 'part of', 'tail': 'UCC', 'meta': {'spans': [[91, 219]]}}
# Relations for Chunk_33:
# {'head': 'Annalise Murphy', 'type': 'employer', 'tail': 'Leicester City Football Club', 'meta': {'spans': [[0, 128], [65, 193]]}}
# {'head': 'Susan Whelan', 'type': 'employer', 'tail': 'Leicester City Football Club', 'meta': {'spans': [[0, 128], [65, 193]]}}
# {'head': 'Annalise Murphy', 'type': 'member of sports team', 'tail': 'Leicester City Football Club', 'meta': {'spans': [[0, 128]]}}
# Relations for Chunk_34:
# {'head': 'Enda Kenny', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Enda Kenny', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Enda Kenny', 'type': 'position held', 'tail': 'Leader of Fine Gael', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Enda Kenny', 'type': 'position held', 'tail': 'Minister for Defence', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Enda Kenny', 'type': 'position held', 'tail': 'Leader of the Opposition', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Enda Kenny', 'type': 'position held', 'tail': 'Minister for Tourism and Trade', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Taoiseach', 'type': 'different from', 'tail': 'Minister for Defence', 'meta': {'spans': [[81, 209]]}}
# {'head': 'Minister for Defence', 'type': 'different from', 'tail': 'Taoiseach', 'meta': {'spans': [[81, 209]]}}
# {'head': 'Leader of Fine Gael', 'type': 'different from', 'tail': 'Taoiseach', 'meta': {'spans': [[81, 209]]}}
# {'head': 'Minister of State at the Department of Labour and Department of Education', 'type': 'different from', 'tail': 'Minister for Defence', 'meta': {'spans': [[81, 209]]}}
# Relations for Chunk_35:
# {'head': '2016 election', 'type': 'point in time', 'tail': '6 May 2016', 'meta': {'spans': [[0, 128]]}}
# {'head': '19941997', 'type': 'point in time', 'tail': '1994', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Garret FitzGerald', 'type': 'candidacy in election', 'tail': '1982', 'meta': {'spans': [[0, 128]]}}
# {'head': '1982', 'type': 'successful candidate', 'tail': 'Garret FitzGerald', 'meta': {'spans': [[0, 128]]}}
# {'head': '1982', 'type': 'point in time', 'tail': '1982', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Leo Varadkar', 'type': 'position held', 'tail': 'Leader of Fine Gael', 'meta': {'spans': [[88, 216]]}}
# {'head': 'Leo Varadkar', 'type': 'position held', 'tail': 'Minister for Social Protection', 'meta': {'spans': [[88, 216]]}}
# Relations for Chunk_36:
# {'head': 'Castlebar', 'type': 'located in the administrative territorial entity', 'tail': 'County Mayo', 'meta': {'spans': [[0, 128]]}}
# {'head': 'St Geralds College Castlebar', 'type': 'located in the administrative territorial entity', 'tail': 'County Mayo', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Islandeady GAA', 'type': 'located in the administrative territorial entity', 'tail': 'County Mayo', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Henry Kenny', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[89, 217]]}}
# {'head': 'Henry Kenny', 'type': 'child', 'tail': 'Enda Kenny', 'meta': {'spans': [[89, 217]]}}
# {'head': 'Enda Kenny', 'type': 'father', 'tail': 'Henry Kenny', 'meta': {'spans': [[89, 217]]}}
# {'head': 'Enda Kenny', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[89, 217]]}}
# Relations for Chunk_37:
# {'head': 'Garret FitzGerald', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[0, 128], [70, 198]]}}
# {'head': 'New Ireland Forum', 'type': 'point in time', 'tail': '1983', 'meta': {'spans': [[0, 128], [70, 198]]}}
# {'head': '1981', 'type': 'point in time', 'tail': '1981', 'meta': {'spans': [[70, 198]]}}
# {'head': '1981', 'type': 'followed by', 'tail': '1982', 'meta': {'spans': [[70, 198]]}}
# {'head': '1982', 'type': 'follows', 'tail': '1981', 'meta': {'spans': [[70, 198]]}}
# {'head': '1982', 'type': 'point in time', 'tail': '1982', 'meta': {'spans': [[70, 198]]}}
# Relations for Chunk_38:
# {'head': 'John Bruton Kenny', 'type': 'position held', 'tail': 'Minister for Tourism and Trade', 'meta': {'spans': [[0, 128], [69, 197]]}}
# {'head': 'John Bruton Kenny', 'type': 'member of political party', 'tail': 'Fine GaelLabour Party', 'meta': {'spans': [[0, 128]]}}
# {'head': 'John Bruton Kenny', 'type': 'member of political party', 'tail': 'Fine GaelLabour PartyDemocratic Left Rainbow Coalition', 'meta': {'spans': [[0, 128]]}}
# {'head': 'John Bruton Kenny', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[69, 197]]}}
# Relations for Chunk_39:
# {'head': '1998 Tour de France', 'type': 'point in time', 'tail': '1998', 'meta': {'spans': [[0, 128]]}}
# {'head': 'leadership election', 'type': 'successful candidate', 'tail': 'Michael Noonan', 'meta': {'spans': [[0, 128], [76, 204]]}}
# {'head': 'John Bruton', 'type': 'candidacy in election', 'tail': 'general election', 'meta': {'spans': [[0, 128]]}}
# {'head': 'subsequent leadership election', 'type': 'successful candidate', 'tail': 'Michael Noonan', 'meta': {'spans': [[76, 204]]}}
# {'head': 'Michael Noonan', 'type': 'candidacy in election', 'tail': 'subsequent leadership election', 'meta': {'spans': [[76, 204]]}}
# Relations for Chunk_40:
# {'head': 'Patrice Lumumbumb', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Patrice Lumumbumb', 'type': 'instance of', 'tail': 'racist remarks', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Patrice Lumumbumb', 'type': 'significant event', 'tail': 'racist remarks', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Patrice Lumumba', 'type': 'position held', 'tail': 'Prime Minister of the Democratic Republic of the Congo', 'meta': {'spans': [[58, 186]]}}
# {'head': 'Patrice Lumumba', 'type': 'country of citizenship', 'tail': 'Democratic Republic of the Congo', 'meta': {'spans': [[58, 186]]}}
# {'head': 'Patrice Lumumba', 'type': 'position held', 'tail': 'Prime Minister', 'meta': {'spans': [[58, 186]]}}
# {'head': 'Prime Minister', 'type': 'country', 'tail': 'Democratic Republic of the Congo', 'meta': {'spans': [[58, 186]]}}
# {'head': 'Democratic Republic of the Congo', 'type': 'office held by head of government', 'tail': 'Prime Minister', 'meta': {'spans': [[58, 186]]}}
# Relations for Chunk_41:
# {'head': 'Leader of the Opposition 2002', 'type': 'point in time', 'tail': '2002', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Leader of the Opposition 20022011', 'type': 'point in time', 'tail': '2002', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Leader of the Opposition', 'type': 'appointed by', 'tail': 'Taoiseach', 'meta': {'spans': [[0, 128]]}}
# {'head': '2004 Local and European elections', 'type': 'point in time', 'tail': '2004', 'meta': {'spans': [[80, 208]]}}
# {'head': '1927 gen', 'type': 'point in time', 'tail': '1927', 'meta': {'spans': [[80, 208]]}}
# {'head': '2004 Local', 'type': 'point in time', 'tail': '2004', 'meta': {'spans': [[80, 208]]}}
# {'head': 'European elections', 'type': 'point in time', 'tail': '2004', 'meta': {'spans': [[80, 208]]}}
# Relations for Chunk_42:
# {'head': 'German chancellor', 'type': 'officeholder', 'tail': 'Angela Merkel', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Angela Merkel', 'type': 'position held', 'tail': 'German chancellor', 'meta': {'spans': [[0, 128]]}}
# {'head': 'chancellor', 'type': 'officeholder', 'tail': 'Angela Merkel', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Angela Merkel', 'type': 'position held', 'tail': 'chancellor', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Michael Ring', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[72, 200]]}}
# {'head': 'Michael Ring Kenny', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[72, 200]]}}
# {'head': 'Michael Ring', 'type': 'member of political party', 'tail': 'Mayo Fine Gael', 'meta': {'spans': [[72, 200]]}}
# Relations for Chunk_43:
# {'head': 'European Peoples Party', 'type': 'political ideology', 'tail': 'populist', 'meta': {'spans': [[0, 128]]}}
# {'head': 'European Peoples Party', 'type': 'instance of', 'tail': 'European political group', 'meta': {'spans': [[0, 128]]}}
# {'head': 'European Peoples Party EPP', 'type': 'political ideology', 'tail': 'populist', 'meta': {'spans': [[0, 128]]}}
# {'head': '2007 general election', 'type': 'point in time', 'tail': '24 May 2007', 'meta': {'spans': [[72, 200]]}}
# {'head': '2007 general election', 'type': 'candidate', 'tail': 'Labour Party', 'meta': {'spans': [[72, 200]]}}
# {'head': 'European', 'type': 'point in time', 'tail': '2007', 'meta': {'spans': [[72, 200]]}}
# Relations for Chunk_44:
# {'head': 'Contract for a Better Ireland36', 'type': 'inception', 'tail': 'March 2007', 'meta': {'spans': [[0, 128]]}}
# {'head': 'contract for a Better Ireland36', 'type': 'inception', 'tail': 'March 2007', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Kennys leadership', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Leaders debate', 'type': 'participant', 'tail': 'Bertie Ahern', 'meta': {'spans': [[56, 184]]}}
# {'head': 'Contract for a Better Ireland', 'type': 'inception', 'tail': 'March 2007', 'meta': {'spans': [[56, 184]]}}
# {'head': 'Contract for a Better Ireland', 'type': 'point in time', 'tail': 'March 2007', 'meta': {'spans': [[56, 184]]}}
# Relations for Chunk_45:
# {'head': 'banking crisis', 'type': 'location', 'tail': 'County Cork', 'meta': {'spans': [[0, 128]]}}
# {'head': 'banking crisis in County Cork', 'type': 'start time', 'tail': '15 February 2009', 'meta': {'spans': [[0, 128]]}}
# {'head': 'banking crisis in County Cork', 'type': 'point in time', 'tail': '15 February 2009', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Enda Kenny', 'type': 'member of political party', 'tail': 'European Peoples Party', 'meta': {'spans': [[81, 209]]}}
# {'head': 'Enda Kenny', 'type': 'position held', 'tail': 'VicePresident of the European Peoples Party', 'meta': {'spans': [[81, 209]]}}
# {'head': 'Enda Kenny', 'type': 'position held', 'tail': 'VicePresident of the EPP', 'meta': {'spans': [[81, 209]]}}
# Relations for Chunk_46:
# {'head': '2010 leadership challenge', 'type': 'point in time', 'tail': '2010', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Irish financial crisis', 'type': 'point in time', 'tail': '2010', 'meta': {'spans': [[0, 128]]}}
# {'head': '2010 leadership challenge', 'type': 'point in time', 'tail': '10 June 2010', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Richard Bruton', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[84, 212]]}}
# {'head': 'Richard Bruton', 'type': 'member of political party', 'tail': 'Fianna Fáil', 'meta': {'spans': [[84, 212]]}}
# Relations for Chunk_47:
# {'head': 'Vincent Browne', 'type': 'employer', 'tail': 'The Irish Times', 'meta': {'spans': [[0, 128]]}}
# {'head': 'motion of confidence in his leadership', 'type': 'point in time', 'tail': '17 June 2010', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Fine Gael', 'type': 'chairperson', 'tail': 'Simon Coveney', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Simon Coveney', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[0, 128]]}}
# {'head': '2011 general election campaign', 'type': 'point in time', 'tail': '2011', 'meta': {'spans': [[92, 220]]}}
# {'head': 'Bruton Coveney', 'type': 'candidacy in election', 'tail': '2011 general election', 'meta': {'spans': [[92, 220]]}}
# Relations for Chunk_48:
# {'head': 'party election headquarters', 'type': 'located in the administrative territorial entity', 'tail': 'Dublin', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Fine Gael', 'type': 'headquarters location', 'tail': 'Dublin', 'meta': {'spans': [[0, 128]]}}
# {'head': 'party election headquarters', 'type': 'occupant', 'tail': 'Fine Gael', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Enda Kenny', 'type': 'employer', 'tail': 'TV3 RTÉ', 'meta': {'spans': [[73, 201]]}}
# {'head': 'Enda Kenny', 'type': 'employer', 'tail': 'RTÉ', 'meta': {'spans': [[73, 201]]}}
# {'head': 'Enda Kenny', 'type': 'employer', 'tail': 'TG4', 'meta': {'spans': [[73, 201]]}}
# Relations for Chunk_49:
# {'head': 'Richard Bruton', 'type': 'position held', 'tail': 'TD', 'meta': {'spans': [[0, 128]]}}
# {'head': 'The Late Late Show', 'type': 'cast member', 'tail': 'Vincent Browne', 'meta': {'spans': [[0, 128]]}}
# {'head': 'previous leadership challenge to Kenny', 'type': 'participant', 'tail': 'Richard Bruton', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Richard Bruton', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[90, 218]]}}
# {'head': 'Richard Bruton', 'type': 'member of political party', 'tail': 'Fine Gaels', 'meta': {'spans': [[90, 218]]}}
# {'head': 'previous leadership challenge', 'type': 'participant', 'tail': 'Richard Bruton', 'meta': {'spans': [[90, 218]]}}
# Relations for Chunk_50:
# {'head': 'German Chancellor', 'type': 'officeholder', 'tail': 'Angela Merkel', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Angela Merkel', 'type': 'position held', 'tail': 'German Chancellor', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Angela Merkel', 'type': 'member of political party', 'tail': 'Merkels CDU', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Merkels CDU', 'type': 'chairperson', 'tail': 'Angela Merkel', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Merkels CDU', 'type': 'member of', 'tail': 'European Peoples Party', 'meta': {'spans': [[0, 128]]}}
# {'head': 'European Peoples Party', 'type': 'has part', 'tail': 'Merkels CDU', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Angela Merkel', 'type': 'member of political party', 'tail': 'Merkels CDU party', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Merkels CDU party', 'type': 'chairperson', 'tail': 'Angela Merkel', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Merkels CDU party', 'type': 'member of', 'tail': 'European Peoples Party', 'meta': {'spans': [[0, 128]]}}
# {'head': 'European Peoples Party', 'type': 'has part', 'tail': 'Merkels CDU party', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Enda Kenny', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[84, 212]]}}
# {'head': 'Enda Kenny', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[84, 212]]}}
# {'head': 'Enda Kenny', 'type': 'candidacy in election', 'tail': '2007 election', 'meta': {'spans': [[84, 212]]}}
# {'head': '2007 election', 'type': 'successful candidate', 'tail': 'Enda Kenny', 'meta': {'spans': [[84, 212]]}}
# Relations for Chunk_51:
# {'head': 'his Mayo constituency', 'type': 'country', 'tail': 'history of the Irish state', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Fianna Fáil', 'type': 'located in the administrative territorial entity', 'tail': 'Mayo', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Fianna Fáil', 'type': 'significant event', 'tail': 'history of the Irish state its representation being reduced by 75', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Eamon Gilmore', 'type': 'position held', 'tail': 'Tánaiste', 'meta': {'spans': [[66, 194]]}}
# {'head': 'Eamon Gilmore', 'type': 'member of political party', 'tail': 'Labour Party', 'meta': {'spans': [[66, 194]]}}
# {'head': 'Tánaiste', 'type': 'officeholder', 'tail': 'Eamon Gilmore', 'meta': {'spans': [[66, 194]]}}
# Relations for Chunk_52:
# {'head': 'Barack Obama', 'type': 'position held', 'tail': 'US president', 'meta': {'spans': [[0, 128]]}}
# {'head': '31st Dáil', 'type': 'inception', 'tail': '9 March 2011', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Mary McAleese', 'type': 'position held', 'tail': 'President', 'meta': {'spans': [[0, 128], [93, 221]]}}
# {'head': 'President', 'type': 'officeholder', 'tail': 'Mary McAleese', 'meta': {'spans': [[93, 221]]}}
# {'head': 'Mary McAleese', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[93, 221]]}}
# Relations for Chunk_53:
# {'head': 'Eamon Gilmores', 'type': 'position held', 'tail': 'Tánaiste', 'meta': {'spans': [[0, 128], [96, 224]]}}
# {'head': 'Eamon Gilmores', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[0, 128], [96, 224]]}}
# Relations for Chunk_54:
# {'head': 'Nicolas Sarkozy', 'type': 'position held', 'tail': 'President of France', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Leaders Questions', 'type': 'start time', 'tail': '31 March 2011', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Leaders Questions', 'type': 'point in time', 'tail': '31 March 2011', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Allied Irish Banks', 'type': 'owned by', 'tail': 'Central Bank of Ireland', 'meta': {'spans': [[58, 186]]}}
# {'head': 'Allied Irish Banks', 'type': 'parent organization', 'tail': 'Central Bank of Ireland', 'meta': {'spans': [[58, 186]]}}
# {'head': 'Irish Life', 'type': 'owned by', 'tail': 'Central Bank of Ireland', 'meta': {'spans': [[58, 186]]}}
# Relations for Chunk_55:
# {'head': '2011', 'type': 'point in time', 'tail': '2011', 'meta': {'spans': [[0, 128], [60, 188]]}}
# {'head': '2011 also saw the election', 'type': 'point in time', 'tail': '2011', 'meta': {'spans': [[0, 128]]}}
# {'head': 'first national opinion poll', 'type': 'publication date', 'tail': '10 April 2011', 'meta': {'spans': [[0, 128], [60, 188]]}}
# {'head': 'Kenny', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[60, 188]]}}
# Relations for Chunk_56:
# {'head': 'Eurozone', 'type': 'has part', 'tail': 'Irelands', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Irelands', 'type': 'member of', 'tail': 'Eurozone', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Pension levy controversy', 'type': 'point in time', 'tail': '9 May 2011', 'meta': {'spans': [[0, 128]]}}
# {'head': '2011 Kennys government', 'type': 'point in time', 'tail': '2011', 'meta': {'spans': [[68, 196]]}}
# {'head': '06 tax levy', 'type': 'point in time', 'tail': '2011', 'meta': {'spans': [[68, 196]]}}
# {'head': '06 tax levy on private pension savings', 'type': 'point in time', 'tail': '2011', 'meta': {'spans': [[68, 196]]}}
# Relations for Chunk_57:
# {'head': 'TDs', 'type': 'part of', 'tail': 'Dáil', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Dáil', 'type': 'has part', 'tail': 'TDs', 'meta': {'spans': [[0, 128]]}}
# {'head': '2011 presidential election', 'type': 'point in time', 'tail': '2011', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Cloyne Report', 'type': 'publication date', 'tail': '13 July 2011', 'meta': {'spans': [[76, 204]]}}
# {'head': 'Constitutional Convention', 'type': 'point in time', 'tail': '2011', 'meta': {'spans': [[76, 204]]}}
# {'head': 'Constitutional Convention in 2011', 'type': 'point in time', 'tail': '2011', 'meta': {'spans': [[76, 204]]}}
# Relations for Chunk_58:
# {'head': 'John Magee', 'type': 'diocese', 'tail': 'Roman Catholic Diocese of Cloyne', 'meta': {'spans': [[0, 128]]}}
# {'head': 'John Magee', 'type': 'position held', 'tail': 'Bishop', 'meta': {'spans': [[0, 128]]}}
# {'head': 'John Magee', 'type': 'position held', 'tail': 'Bishop of the Diocese', 'meta': {'spans': [[0, 128]]}}
# {'head': '1996 guidelines', 'type': 'point in time', 'tail': '1996', 'meta': {'spans': [[61, 189]]}}
# {'head': '1996 guidelines', 'type': 'publication date', 'tail': '1996', 'meta': {'spans': [[61, 189]]}}
# {'head': 'Diocese', 'type': 'country', 'tail': 'Vatican', 'meta': {'spans': [[61, 189]]}}
# Relations for Chunk_59:
# {'head': 'paedophilepriest scandals', 'type': 'point in time', 'tail': '17 years', 'meta': {'spans': [[0, 128]]}}
# {'head': '17 years of paedophilepriest scandals', 'type': 'point in time', 'tail': '17', 'meta': {'spans': [[0, 128]]}}
# {'head': '17 years of paedophilepriest scandals', 'type': 'point in time', 'tail': '17 years', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Holy See', 'type': 'instance of', 'tail': 'sovereign democratic republic', 'meta': {'spans': [[61, 189]]}}
# {'head': 'Roman Catholic church', 'type': 'authority', 'tail': 'Holy See', 'meta': {'spans': [[61, 189]]}}
# Relations for Chunk_60:
# {'head': 'Donum Veritatis The Gift of the Truth', 'type': 'publication date', 'tail': '24 May 1990', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Instruction on the Ecclesial Vocation of the Theologian', 'type': 'publication date', 'tail': '24 May 1990', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Instruction on the Ecclesial Vocation of the Theologian otherwise known as Donum Veritatis The Gift of the Truth', 'type': 'publication date', 'tail': '24 May 1990', 'meta': {'spans': [[0, 128]]}}
# {'head': '2012 Irish budget', 'type': 'point in time', 'tail': '2012', 'meta': {'spans': [[83, 211]]}}
# {'head': 'Cardinal Ratzinger', 'type': 'position held', 'tail': 'Prefect', 'meta': {'spans': [[83, 211]]}}
# {'head': 'Prefect', 'type': 'different from', 'tail': 'Secretary of the Congregation', 'meta': {'spans': [[83, 211]]}}
# {'head': 'Secretary of the Congregation', 'type': 'different from', 'tail': 'Prefect', 'meta': {'spans': [[83, 211]]}}
# Relations for Chunk_61:
# {'head': 'Seán Lemass', 'type': 'employer', 'tail': 'Time magazine', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Seán Lemass', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Seán Lemass', 'type': 'notable work', 'tail': 'Time magazine cover', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Kenny', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[75, 203]]}}
# {'head': 'Taoiseach', 'type': 'part of', 'tail': 'Irish public', 'meta': {'spans': [[75, 203]]}}
# {'head': 'Kennys', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[75, 203]]}}
# Relations for Chunk_62:
# {'head': 'European of the Year', 'type': 'conferred by', 'tail': 'VDZ', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Golden Victoria European of the Year 2012', 'type': 'conferred by', 'tail': 'VDZ', 'meta': {'spans': [[0, 128]]}}
# {'head': 'European of the Year 2012', 'type': 'point in time', 'tail': '2012', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Enda Kenny', 'type': 'position held', 'tail': 'Prime Minister', 'meta': {'spans': [[74, 202]]}}
# {'head': 'Enda Kenny', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[74, 202]]}}
# Relations for Chunk_63:
# {'head': 'Enda Kenny', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[0, 128], [80, 208]]}}
# {'head': 'Nobel Peace Prize', 'type': 'winner', 'tail': 'Thorbjorn Jagland', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Thorbjorn Jagland', 'type': 'award received', 'tail': 'Nobel Peace Prize', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Presidency of the Council of the European Union', 'type': 'country', 'tail': 'Ireland', 'meta': {'spans': [[80, 208]]}}
# {'head': 'Presidency of the Council of the European Union', 'type': 'inception', 'tail': '2013', 'meta': {'spans': [[80, 208]]}}
# Relations for Chunk_64:
# {'head': 'Enda Kenny', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Taoiseach', 'type': 'officeholder', 'tail': 'Enda Kenny', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Common Agricultural Policy', 'type': 'has part', 'tail': 'CAP', 'meta': {'spans': [[0, 128]]}}
# {'head': 'CAP', 'type': 'part of', 'tail': 'Common Agricultural Policy', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Dromoland Castle', 'type': 'located in the administrative territorial entity', 'tail': 'Clare', 'meta': {'spans': [[86, 214]]}}
# {'head': 'Ashford Castle', 'type': 'located in the administrative territorial entity', 'tail': 'Mayo', 'meta': {'spans': [[86, 214]]}}
# {'head': 'Eamon Gil', 'type': 'position held', 'tail': 'Tánaiste', 'meta': {'spans': [[86, 214]]}}
# Relations for Chunk_65:
# {'head': 'Anglo Irish Bank', 'type': 'owned by', 'tail': 'European Central Bank', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Promissory note used to bail out', 'type': 'participant', 'tail': 'European Central Bank', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Promissory note', 'type': 'owned by', 'tail': 'European Central Bank', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Dáil Éireann', 'type': 'country', 'tail': 'State', 'meta': {'spans': [[83, 211]]}}
# {'head': 'Magdalene laundries apology', 'type': 'point in time', 'tail': '19 February 2013', 'meta': {'spans': [[83, 211]]}}
# {'head': 'Magdalene laundries apology', 'type': 'publication date', 'tail': '19 February 2013', 'meta': {'spans': [[83, 211]]}}
# Relations for Chunk_66:
# {'head': 'Enda Kenny', 'type': 'position held', 'tail': 'European Council president', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Enda Kenny', 'type': 'position held', 'tail': 'European Commission president', 'meta': {'spans': [[0, 128]]}}
# ...
# Relations for Chunk_87:
# {'head': '2011 election campaign', 'type': 'point in time', 'tail': '2011', 'meta': {'spans': [[0, 128], [80, 208]]}}
# {'head': 'the 2011 election campaign', 'type': 'point in time', 'tail': '2011', 'meta': {'spans': [[0, 128]]}}
# {'head': '2011 election', 'type': 'point in time', 'tail': '2011', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Enda Kenny', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[80, 208]]}}
# {'head': '2011 election campaign', 'type': 'candidate', 'tail': 'Enda Kenny', 'meta': {'spans': [[80, 208]]}}
# {'head': 'Enda Kenny', 'type': 'candidacy in election', 'tail': '2011 election campaign', 'meta': {'spans': [[80, 208]]}}
# Relations for Chunk_88:
# {'head': 'Seán Kelly', 'type': 'position held', 'tail': 'President', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Enda Kenny', 'type': 'spouse', 'tail': 'Fionnuala OKelly', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Fionnuala OKelly', 'type': 'spouse', 'tail': 'Enda Kenny', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Kilcummin', 'type': 'located in the administrative territorial entity', 'tail': 'County Kerry', 'meta': {'spans': [[102, 230]]}}
# {'head': 'Killarney', 'type': 'located in the administrative territorial entity', 'tail': 'County Kerry', 'meta': {'spans': [[102, 230]]}}
# {'head': 'Seán Kelly', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[102, 230]]}}
# {'head': 'Seán Kelly', 'type': 'position held', 'tail': 'MEP', 'meta': {'spans': [[102, 230]]}}
# Relations for Chunk_89:
# {'head': 'Simon Coveney', 'type': 'date of birth', 'tail': '16 June 1972', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Simon Coveney', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[0, 128], [83, 211]]}}
# {'head': 'Simon Coveney', 'type': 'position held', 'tail': 'Minister', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Minister', 'type': 'officeholder', 'tail': 'Simon Coveney', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Simon Coveney', 'type': 'position held', 'tail': 'Minister for Enterprise Trade and Employment', 'meta': {'spans': [[83, 211]]}}
# {'head': 'Simon Coveney', 'type': 'position held', 'tail': 'Tánaiste', 'meta': {'spans': [[83, 211]]}}
# {'head': 'Simon Coveney', 'type': 'position held', 'tail': 'Teachta Dála', 'meta': {'spans': [[83, 211]]}}
# {'head': 'Simon Coveney', 'type': 'father', 'tail': 'Hugh Coveney', 'meta': {'spans': [[83, 211]]}}
# {'head': 'Minister for Enterprise Trade and Employment', 'type': 'officeholder', 'tail': 'Simon Coveney', 'meta': {'spans': [[83, 211]]}}
# {'head': 'Fine Gael', 'type': 'chairperson', 'tail': 'Simon Coveney', 'meta': {'spans': [[83, 211]]}}
# {'head': 'Hugh Coveney', 'type': 'child', 'tail': 'Simon Coveney', 'meta': {'spans': [[83, 211]]}}
# {'head': 'Hugh Coveney', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[83, 211]]}}
# {'head': 'Hugh Coveney', 'type': 'position held', 'tail': 'Teachta Dála', 'meta': {'spans': [[83, 211]]}}
# Relations for Chunk_90:
# {'head': 'Patrick Coveney', 'type': 'position held', 'tail': 'Member of the European Parliament', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Clongowes Wood College', 'type': 'located in the administrative territorial entity', 'tail': 'County Kildare', 'meta': {'spans': [[0, 128], [77, 205]]}}
# {'head': 'Member of the European Parliament', 'type': 'subclass of', 'tail': 'MEP', 'meta': {'spans': [[0, 128]]}}
# {'head': 'MEP', 'type': 'has part', 'tail': 'Member of the European Parliament', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Patrick Coveney Simon', 'type': 'educated at', 'tail': 'University College Cork', 'meta': {'spans': [[77, 205]]}}
# {'head': 'University College Cork', 'type': 'located in the administrative territorial entity', 'tail': 'Cork', 'meta': {'spans': [[77, 205]]}}
# Relations for Chunk_91:
# {'head': 'John Bruton', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[0, 128]]}}
# {'head': 'byelection', 'type': 'point in time', 'tail': '1998', 'meta': {'spans': [[0, 128]]}}
# {'head': 'leadership heave', 'type': 'point in time', 'tail': '2001', 'meta': {'spans': [[0, 128]]}}
# {'head': '2002 general election', 'type': 'successful candidate', 'tail': 'Enda Kenny', 'meta': {'spans': [[95, 223]]}}
# {'head': 'Enda Kenny', 'type': 'candidacy in election', 'tail': '2002 general election', 'meta': {'spans': [[95, 223]]}}
# Relations for Chunk_92:
# {'head': 'Member of the European Parliament', 'type': 'part of', 'tail': 'European Parliament', 'meta': {'spans': [[0, 128]]}}
# {'head': 'European Parliament', 'type': 'has part', 'tail': 'Member of the European Parliament', 'meta': {'spans': [[0, 128]]}}
# {'head': '2004 European Parliament election', 'type': 'office contested', 'tail': 'Member of the European Parliament', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Member of the European Parliament 2004', 'type': 'point in time', 'tail': '2004', 'meta': {'spans': [[0, 128]]}}
# {'head': '2004 European Parliament election', 'type': 'office contested', 'tail': 'Member of the European Parliament 2004', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Member of the European Parliament 20042007', 'type': 'point in time', 'tail': '2004', 'meta': {'spans': [[0, 128]]}}
# {'head': '2004 European Parliament election', 'type': 'office contested', 'tail': 'Member of the European Parliament 20042007', 'meta': {'spans': [[0, 128]]}}
# {'head': 'European Parliament', 'type': 'has part', 'tail': 'Foreign Affairs Committee', 'meta': {'spans': [[72, 200]]}}
# {'head': 'Foreign Affairs Committee', 'type': 'part of', 'tail': 'European Parliament', 'meta': {'spans': [[72, 200]]}}
# {'head': 'European Parliament', 'type': 'has part', 'tail': 'MEP', 'meta': {'spans': [[72, 200]]}}
# {'head': 'MEP', 'type': 'part of', 'tail': 'European Parliament', 'meta': {'spans': [[72, 200]]}}
# {'head': 'Colm Bu', 'type': 'position held', 'tail': 'MEP', 'meta': {'spans': [[72, 200]]}}
# Relations for Chunk_93:
# {'head': 'Enda Kenny Kenny', 'type': 'candidacy in election', 'tail': '2011 general election', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Enda Kenny Kenny', 'type': 'member of political party', 'tail': 'Fine GaelLabour Party', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Minister for Agriculture Food and the Marine', 'type': 'inception', 'tail': '9 March 2011', 'meta': {'spans': [[82, 210]]}}
# {'head': 'coalition government', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[82, 210]]}}
# {'head': 'Fine Gael', 'type': 'follows', 'tail': 'Labour Party', 'meta': {'spans': [[82, 210]]}}
# Relations for Chunk_94:
# {'head': 'cabinet reshuffle', 'type': 'point in time', 'tail': '11 July 2014', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Eamon Gilmore', 'type': 'position held', 'tail': 'Tánaiste', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Department of Defence', 'type': 'subsidiary', 'tail': 'Air Corps', 'meta': {'spans': [[74, 202]]}}
# {'head': 'White Paper on Defence', 'type': 'publication date', 'tail': 'August 2015', 'meta': {'spans': [[74, 202]]}}
# Relations for Chunk_95:
# {'head': 'Regina Doherty', 'type': 'position held', 'tail': 'Chief Whip', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Regina Doherty', 'type': 'member of political party', 'tail': 'Fianna Fáil', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Minister for Defence', 'type': 'subclass of', 'tail': 'Minister', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Micheál Martin', 'type': 'member of political party', 'tail': 'Fianna Fáil', 'meta': {'spans': [[69, 197]]}}
# {'head': 'Enda Kenn', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[69, 197]]}}
# {'head': 'Enda Kenn', 'type': 'position held', 'tail': 'Minister for Housing Planning Community and Local Government', 'meta': {'spans': [[69, 197]]}}
# Relations for Chunk_96:
# {'head': 'Michael Creed', 'type': 'position held', 'tail': 'Minister for Agriculture', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Minister for Agriculture', 'type': 'officeholder', 'tail': 'Michael Creed', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Antony Blinken', 'type': 'position held', 'tail': 'US Secretary of State', 'meta': {'spans': [[0, 128], [86, 214]]}}
# {'head': 'Charles Flanagan', 'type': 'position held', 'tail': 'Minister for Justice and Equality', 'meta': {'spans': [[86, 214]]}}
# Relations for Chunk_97:
# {'head': 'Micheál Martin', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[0, 128], [85, 213]]}}
# {'head': 'Micheál Martin', 'type': 'member of political party', 'tail': 'Fine Gael Fianna Fáil', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Micheál Martin', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[0, 128], [85, 213]]}}
# {'head': 'Fine Gael', 'type': 'chairperson', 'tail': 'Micheál Martin', 'meta': {'spans': [[85, 213]]}}
# Relations for Chunk_98:
# {'head': 'Ukraine', 'type': 'contains administrative territorial entity', 'tail': 'Kyiv', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Kyiv', 'type': 'country', 'tail': 'Ukraine', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Bucha massacre', 'type': 'located in the administrative territorial entity', 'tail': 'Kyiv', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Kyiv', 'type': 'located in the administrative territorial entity', 'tail': 'Ukraine', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Ukraine', 'type': 'diplomatic relation', 'tail': 'Poland', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Poland', 'type': 'diplomatic relation', 'tail': 'Ukraine', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Council of Europes Committee of Ministers', 'type': 'chairperson', 'tail': 'Luigi Di Maio', 'meta': {'spans': [[82, 210]]}}
# {'head': 'Brexit withdrawal agreement', 'type': 'participant', 'tail': 'European Union', 'meta': {'spans': [[82, 210]]}}
# {'head': 'Luigi Di Maio', 'type': 'member of', 'tail': 'Council of Europes Committee of Ministers', 'meta': {'spans': [[82, 210]]}}
# Relations for Chunk_99:
# {'head': 'backstop', 'type': 'facet of', 'tail': 'Brexit withdrawal agreement', 'meta': {'spans': [[0, 128]]}}
# {'head': 'response to the COVID19 pandemic', 'type': 'facet of', 'tail': 'COVID19 pandemic', 'meta': {'spans': [[0, 128]]}}
# {'head': 'backstop', 'type': 'part of', 'tail': 'Brexit withdrawal agreement', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Micheál Martin', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[75, 203]]}}
# {'head': 'Taoiseach', 'type': 'officeholder', 'tail': 'Micheál Martin', 'meta': {'spans': [[75, 203]]}}
# {'head': 'Katherine Zappone', 'type': 'member of political party', 'tail': 'Independent', 'meta': {'spans': [[75, 203]]}}
# Relations for Chunk_100:
# {'head': 'Leo Varadkar', 'type': 'position held', 'tail': 'Tánaiste', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Tánaiste', 'type': 'officeholder', 'tail': 'Leo Varadkar', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Tánaiste Leo Varadkar', 'type': 'position held', 'tail': 'Tánaiste', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Catherine Ardagh', 'type': 'member of political party', 'tail': 'Fianna Fáil', 'meta': {'spans': [[86, 214]]}}
# Relations for Chunk_101:
# {'head': 'James Lawless', 'type': 'member of political party', 'tail': 'Fianna Fáil', 'meta': {'spans': [[0, 128]]}}
# {'head': 'James Lawless', 'type': 'position held', 'tail': 'Fianna Fáil TD', 'meta': {'spans': [[0, 128]]}}
# {'head': 'James Lawless', 'type': 'position held', 'tail': 'TD', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Taoiseach', 'type': 'different from', 'tail': 'Minister for Foreign Affairs', 'meta': {'spans': [[73, 201]]}}
# {'head': 'Minister for Foreign Affairs', 'type': 'different from', 'tail': 'Taoiseach', 'meta': {'spans': [[73, 201]]}}
# {'head': 'Minister for Enterprise Trade and Employment', 'type': 'different from', 'tail': 'Minister for Foreign Affairs', 'meta': {'spans': [[73, 201]]}}
# {'head': 'Minister for Foreign Affairs', 'type': 'different from', 'tail': 'Minister for Enterprise Trade and Employment', 'meta': {'spans': [[73, 201]]}}
# Relations for Chunk_102:
# {'head': 'Simon Harris', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Simon Harris', 'type': 'position held', 'tail': 'Fine Gael leader', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Fine Gael', 'type': 'chairperson', 'tail': 'Simon Harris', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Michael Creed', 'type': 'date of birth', 'tail': '29 June 1963', 'meta': {'spans': [[87, 215]]}}
# {'head': 'Michael Creed', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[87, 215]]}}
# {'head': 'Michael Creed', 'type': 'position held', 'tail': 'Teachta Dála', 'meta': {'spans': [[87, 215]]}}
# {'head': 'Michael Creed', 'type': 'position held', 'tail': 'Teachta Dála TD', 'meta': {'spans': [[87, 215]]}}
# Relations for Chunk_103:
# {'head': 'Donal Creed', 'type': 'position held', 'tail': 'TD', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Donal Creed', 'type': 'position held', 'tail': 'Minister of State', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Donal Creed', 'type': 'place of birth', 'tail': 'Macroom', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Donal Creed', 'type': 'date of birth', 'tail': '1963', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Donal Creed', 'type': 'educated at', 'tail': 'University College Cork', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Bandon', 'type': 'located in the administrative territorial entity', 'tail': 'County Cork', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Donal Creed', 'type': 'educated at', 'tail': 'St Colmans College Fermoy', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Donal Creed', 'type': 'educated at', 'tail': 'De La Salle College in Macroom', 'meta': {'spans': [[0, 128]]}}
# {'head': '1989 general election', 'type': 'followed by', 'tail': '2002 general election', 'meta': {'spans': [[92, 220]]}}
# {'head': '2002 general election', 'type': 'follows', 'tail': '1989 general election', 'meta': {'spans': [[92, 220]]}}
# {'head': 'Gerard Murphy', 'type': 'member of political party', 'tail': 'Fine Gael', 'meta': {'spans': [[92, 220]]}}
# {'head': 'Gerard Murphy', 'type': 'candidacy in election', 'tail': '2002 general election', 'meta': {'spans': [[92, 220]]}}
# Relations for Chunk_104:
# {'head': 'Gerard Murphy', 'type': 'candidacy in election', 'tail': '2007 general election', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Enda Kenny', 'type': 'candidacy in election', 'tail': '2011 general election', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Richard Brutons', 'type': 'candidacy in election', 'tail': '2011 general election', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Leo Varadkar', 'type': 'position held', 'tail': 'Taoiseach', 'meta': {'spans': [[85, 213]]}}
# {'head': 'Taoiseach', 'type': 'officeholder', 'tail': 'Leo Varadkar', 'meta': {'spans': [[85, 213]]}}
# Relations for Chunk_105:
# {'head': 'coalition government in 2020', 'type': 'has part', 'tail': 'Fine Gael', 'meta': {'spans': [[0, 128]]}}
# {'head': 'coalition government in 2020', 'type': 'has part', 'tail': 'Green Party', 'meta': {'spans': [[0, 128]]}}
# {'head': 'a coalition government in 2020', 'type': 'has part', 'tail': 'Fine Gael', 'meta': {'spans': [[0, 128]]}}
# {'head': 'a coalition government in 2020', 'type': 'has part', 'tail': 'Green Party', 'meta': {'spans': [[0, 128]]}}
# {'head': 'the formation of a coalition government in 2020', 'type': 'has part', 'tail': 'Fine Gael', 'meta': {'spans': [[0, 128]]}}
# {'head': 'the formation of a coalition government in 2020', 'type': 'has part', 'tail': 'Green Party', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Farming and the Burren', 'type': 'publisher', 'tail': 'Teagasc', 'meta': {'spans': [[85, 213]]}}
# {'head': 'Farming and the Burren', 'type': 'owned by', 'tail': 'Teagasc', 'meta': {'spans': [[85, 213]]}}
# {'head': 'Farming and the Burren', 'type': 'publication date', 'tail': '2005', 'meta': {'spans': [[85, 213]]}}
# Relations for Chunk_106:
# {'head': 'NUI Galway', 'type': 'country', 'tail': 'Ireland', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Heritage Council', 'type': 'country', 'tail': 'Ireland', 'meta': {'spans': [[0, 128]]}}
# {'head': 'Ashoka Fellow', 'type': 'inception', 'tail': '2011', 'meta': {'spans': [[0, 128]]}}

# %% [markdown]
# 11. **Storing the extracted relations in a dataframe.**
#
# The relations' dictionaries are stored in a single column of a dataframe, where each row belongs to the relations' dictionary extracted for each chunk.

# %%
relation_df = pd.DataFrame(relations_dict.items())
relation_df = relation_df.rename(columns={0: 'chunk_id', 1: 'triples'})
relation_df.head()
# Out:
#   chunk_id                                            triples
# 0  Chunk_1  [{'head': 'IFA2024', 'type': 'country', 'tail'...
# 1  Chunk_2  [{'head': 'democratic', 'type': 'subclass of',...
# 2  Chunk_3  [{'head': 'Minister for Transport', 'type': 'p...
# 3  Chunk_4  [{'head': 'Shannon', 'type': 'located in the a...
# 4  Chunk_5  [{'head': 'Department of Agriculture Food and ...

# %% [markdown]
# 12. **Flattening into a new dataframe.**
#
# Extracting the relations for each chunks out of the dictionary and storing each part of the relation (head, type, and tail) as a separate column in a new dataframe.

# %%
flattened_data = []
for index, row in df.iterrows():
    for d in row['triples']:
        flattened_data.append({
            'chunk_id': row['chunk_id'],
            'head': d['head'],
            'type': d['type'],
            'tail': d['tail']
        })

new_relation_df = pd.DataFrame(flattened_data)
print("\nNew DataFrame:")
print(new_relation_df)
# Out:
# New DataFrame:
#       chunk_id                    head                    type       tail
# 0      Chunk_1                 IFA2024                 country  Singapore
# 1      Chunk_1                 IFA2024                location  Singapore
# 2      Chunk_1    IFA2024 in Singapore                 country  Singapore
# 3      Chunk_1                 Jam Jar             subclass of    jam jar
# 4      Chunk_1                oak tree  has parts of the class     leaves
# ..         ...                     ...                     ...        ...
# 649  Chunk_105  Farming and the Burren                owned by    Teagasc
# 650  Chunk_105  Farming and the Burren        publication date       2005
# 651  Chunk_106              NUI Galway                 country    Ireland
# 652  Chunk_106        Heritage Council                 country    Ireland
# 653  Chunk_106           Ashoka Fellow               inception       2011
#
# [654 rows x 4 columns]

# %% [markdown]
# 13. Exporting the relations to an excel.
#
# Exporting the extracted relations into an excel to be used further to create a knowledge base in neo4j. This step is done to reduce the need of rerunning the model for the same dataset.

# %%
excel_file = 'triples_data.xlsx'
new_relation_df.to_excel(excel_file, index=False)

print(f"Triples saved to {excel_file}")
# Out:
# Triples saved to triples_data.xlsx
